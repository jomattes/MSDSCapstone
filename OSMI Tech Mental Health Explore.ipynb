# %% [markdown]
# # OSMI Quick EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import Dataset

# %%
osmi_df = pd.read_csv('explore_data/tech_mental_health/OSMI 2019 Mental Health in Tech Survey Results - OSMI Mental Health in Tech Survey 2019.csv')

# %%
osmi_df.head(1).T
# Out:
#                                                                                                     0
# *Are you self-employed?*                                                                        False
# How many employees does your company or organiz...                                             26-100
# Is your employer primarily a tech company/organ...                                               True
# Is your primary role within your company relate...                                               True
# Does your employer provide mental health benefi...                                       I don't know
# Do you know the options for mental health care ...                                                 No
# Has your employer ever formally discussed menta...                                                Yes
# Does your employer offer resources to learn mor...                                                Yes
# ...

# %%
osmi_df.describe()
# Out:
#        Overall, how much importance does your employer place on physical health?  \
# count                                         304.000000
# mean                                            6.328947
# std                                             2.298734
# min                                             0.000000
# 25%                                             5.000000
# 50%                                             7.000000
# 75%                                             8.000000
# max                                            10.000000
#
#        Overall, how much importance does your employer place on mental health?  \
# count                                         304.000000
# mean                                            4.878289
# std                                             2.609007
# min                                             0.000000
# 25%                                             3.000000
# 50%                                             5.000000
# ...

# %%
osmi_df.plot.scatter('If they knew you suffered from a mental health disorder, how do you think that your team members/co-workers would react?',
                     'How willing would you be to share with friends and family that you have a mental illness?')
